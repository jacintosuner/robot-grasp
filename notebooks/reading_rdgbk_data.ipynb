# %%
import numpy as np
import os

# Directory containing the .npz files
npz_file = '/home/jacinto/robot-grasp/data/camera_calibration/robot2camera.npz'
data = np.load(npz_file, allow_pickle=True)

print(data)

npz_file = '/home/jacinto/robot-grasp/data/camera_calibration/cam0_calibration_old.npz'
data = np.load(npz_file, allow_pickle=True)
# Show the keys and values
for key in data.keys():
    print(f"Key: {key}")
    print(f"Value: {data[key]}")
# Out:
# [[ 0.99306732 -0.0508894   0.10596019  0.44521567]
#  [-0.11738742 -0.47629551  0.87141424 -0.8120543 ]
#  [ 0.00612262 -0.8778114  -0.47896729  0.55189552]
#  [ 0.          0.          0.          1.        ]]
# Key: T
# Value: [[ 0.99959341 -0.01830716  0.02186026  0.50037411]
#  [-0.02794859 -0.47721422  0.87834245 -0.77674567]
#  [-0.00564793 -0.87859629 -0.47753185  0.5639562 ]
#  [ 0.          0.          0.          1.        ]]

# %%
import matplotlib.pyplot as plt

# Extract the RGB array from the data
rgb_array = data.item().get('rgb')

# Display the RGB image
plt.imshow(rgb_array)
plt.axis('off')  # Hide the axis
plt.show()
