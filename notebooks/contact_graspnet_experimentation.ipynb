# %%
import numpy as np

# Load the .npz file
data = np.load('/home/jacinto/robot-grasp/third_party/contact_graspnet/results/predictions_contact_graspnet_input.npz', allow_pickle=True)

# Check the keys inside the npz file (optional, to understand its structure)
print("Keys in the .npz file:", data.files)

# Access the 'scores' array
scores = data['scores'].item()
pred_grasps_cam = data['pred_grasps_cam'].item()

pred_grasps_cam[1][np.argmax(scores[1])]
# Out:
# Keys in the .npz file: ['pred_grasps_cam', 'scores', 'contact_pts']
# array([[-0.56253284,  0.8267693 ,  0.00307834,  0.37829885],
#        [-0.7280109 , -0.49709556,  0.4721189 , -0.07426273],
#        [ 0.3918637 ,  0.2633413 ,  0.88152945,  0.54362816],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32)

# %%
print(pred_grasps_cam)
# Out:
# {1: array([[[-5.91478229e-01,  8.06186676e-01,  1.47076929e-02,
#           3.82067531e-01],
#         [-6.76881313e-01, -5.06357074e-01,  5.34260333e-01,
#          -8.43571648e-02],
#         [ 4.38160837e-01,  3.06047976e-01,  8.45192075e-01,
#           5.47477365e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]],
#
#        [[ 3.85536365e-02,  8.83494735e-01, -4.66851860e-01,
#           4.57967937e-01],
#         [-9.55756545e-01,  1.68949977e-01,  2.40801275e-01,
#          -5.31640053e-02],
#         [ 2.91621268e-01,  4.36912954e-01,  8.50919545e-01,
#           5.79752445e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]],
#
#        [[-5.90772890e-02,  9.90797698e-01, -1.21777914e-01,
#           4.14767802e-01],
#         [-9.50913072e-01, -1.87336914e-02,  3.08890641e-01,
#          -5.82818836e-02],
#         [ 3.03766847e-01,  1.34048626e-01,  9.43269134e-01,
# ...

# %%
# Load the .npz file
import numpy as np
data = np.load('/home/jacinto/robot-grasp/data/contact_graspnet_pipeline_results/contact_graspnet_results.npz', allow_pickle=True)

# Check the keys inside the npz file (optional, to understand its structure)
print("Keys in the .npz file:", data.files)

# Access the 'scores' array
scores = data['scores'].item()
pred_grasps_cam = data['pred_grasps_cam'].item()

pred_grasps_cam[1][np.argmax(scores[1])]
pred_grasps_cam[1]
# Out:
# Keys in the .npz file: ['pred_grasps_cam', 'scores', 'contact_pts']
# array([[[-0.78428674,  0.6192562 , -0.03763175,  0.3865566 ],
#         [-0.55569196, -0.67422175,  0.48644793, -0.08394141],
#         [ 0.27586377,  0.40242633,  0.8728988 ,  0.5392902 ],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#        [[-0.05405334, -0.9970506 , -0.05448004,  0.43866825],
#         [ 0.99798566, -0.0521286 , -0.03615286, -0.02771102],
#         [ 0.03320628, -0.05632448,  0.99786013,  0.56888723],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#        [[-0.67334735,  0.7371005 , -0.05732637,  0.39286807],
#         [-0.7088841 , -0.62165713,  0.33320534, -0.06023963],
#         [ 0.20996848,  0.2650007 ,  0.9411099 ,  0.54710627],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#        [[ 0.03596144,  0.9560722 , -0.29091683,  0.44838163],
#         [-0.9559304 ,  0.11778694,  0.26892978, -0.05073276],
# ...
