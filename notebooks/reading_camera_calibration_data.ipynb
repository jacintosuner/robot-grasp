# %%
import pickle

# Specify the path to your .pkl file
file_path = '/home/lifanyu/frankapy/new_calibration/data/new_cam0_data.pkl'

# Open the file and load the data
with open(file_path, 'rb') as file:
    data = pickle.load(file)

# Now you can use the data as needed
print(data)
# Out:
# [(array([[-0.20541952, -0.97790589, -0.0385185 ,  0.51901032],
#        [-0.90910404,  0.20524412, -0.36247479, -0.18233288],
#        [ 0.36237192, -0.03944207, -0.93119727,  0.15081141],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), array([[ 9.76989601e-01,  2.31420257e-02, -2.12027747e-01,
#         -6.28997807e-04],
#        [ 6.74101752e-02, -9.76643444e-01,  2.04018262e-01,
#          1.58102052e-02],
#        [-2.02354114e-01, -2.13616548e-01, -9.55730497e-01,
#          6.56525251e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]])), (array([[ 0.09105391, -0.98366112, -0.15524563,  0.5370636 ],
#        [-0.97833719, -0.05926406, -0.19830687, -0.22577065],
#        [ 0.18586627,  0.16993919, -0.96776711,  0.13385119],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), array([[ 0.98437236,  0.14685676,  0.09718097,  0.0387421 ],
#        [ 0.10272097, -0.92708736,  0.3604961 ,  0.05936195],
#        [ 0.14303654, -0.34487987, -0.92768444,  0.61968443],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])), (array([[ 0.02122328, -0.99734078, -0.06958285,  0.51167615],
#        [-0.99821897, -0.01726987, -0.05693365, -0.00927929],
#        [ 0.05558057,  0.07066724, -0.99595019,  0.05060995],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), array([[ 0.99757472,  0.05926627,  0.03649909,  0.00145708],
#        [ 0.03326497, -0.86657394,  0.4979388 ,  0.0398132 ],
#        [ 0.06114014, -0.49551702, -0.86644375,  0.83369593],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])), (array([[-0.06513325, -0.9547205 ,  0.29025642,  0.61177384],
#        [-0.98504678,  0.10799213,  0.13417019, -0.32166562],
#        [-0.15944044, -0.27717721, -0.94749647,  0.14835487],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), array([[-0.46624195,  0.53645854, -0.70344202, -0.19075336],
#        [ 0.85780573,  0.07972728, -0.50775278,  0.09168291],
#        [-0.21630479, -0.84015225, -0.49734941,  0.32405585],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))]
