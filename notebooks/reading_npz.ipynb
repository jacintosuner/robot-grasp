# %%
import numpy as np

file_path = "/home/jacinto/robot-grasp/data/contact_graspnet_pipeline_results_20241217_160921/contact_graspnet_results.npz"
data = np.load(file_path, allow_pickle=True)

print(data.files)
scores = data['scores']
print(scores)
# Out:
# ['pred_grasps_cam', 'scores', 'contact_pts']
# {-1: array([0.30321443, 0.20358592, 0.23507294, 0.18682659, 0.18585855,
#        0.19241008, 0.2710072 , 0.2146754 , 0.2066514 , 0.4008807 ,
#        0.23090285, 0.22670801, 0.32571608, 0.23852019, 0.4169368 ,
#        0.36830387, 0.23873809, 0.18353222, 0.19331202, 0.2687067 ,
#        0.22601621, 0.32542133, 0.24137418, 0.20483428, 0.32284275,
#        0.23976856, 0.23944925, 0.25064313, 0.26964474, 0.33592   ,
#        0.215493  , 0.19988187, 0.24121143, 0.22398028, 0.20638028,
#        0.19098179, 0.43666485, 0.19673198, 0.38560072, 0.18568654,
#        0.21661061, 0.20429835, 0.44878453, 0.26246968, 0.19437492,
#        0.29224366, 0.24316402, 0.33133033, 0.22951137, 0.2593897 ,
#        0.3198847 , 0.35069162, 0.39479244, 0.18354338, 0.2266348 ,
#        0.28102803, 0.25226882, 0.29816827, 0.25694114, 0.18479948,
#        0.27127573, 0.1955118 , 0.18525583, 0.24934141, 0.37959605,
# ...
